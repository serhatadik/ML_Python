# %% [markdown]
# ### ANN

# %%
from IPython.display import Image
# path = ""
Image(data = path, width=600)

# %%
from IPython.display import Image
# path = ""
Image(data = path, width=600)

# %%
from IPython.display import Image
# path = ""
Image(data = path, width=600)

# %%
from IPython.display import Image
# path = ""
Image(data = path, width=300)

# %%
from IPython.display import Image
# path = ""
Image(data = path, width=600)

# %%
from IPython.display import Image
# path = ""
Image(data = path, width=300)

# %%
from keras.models import Sequential
from keras.layers import Dense

input_shape = (len(x_train.columns),)
num_classes=3

y_trainn = np.zeros((len(y_train),num_classes))
y_testt = np.zeros((len(y_test),num_classes))

for i in range(len(y_train)):
    if y_train[i] == classes[0]:
        y_trainn[i,:] = [1,0,0]
    elif y_train[i] == classes[1]:
        y_trainn[i,:] = [0,1,0]
    elif y_train[i] == classes[2]:
        y_trainn[i,:] = [0,0,1]

for i in range(len(y_test)):
    if y_test[i] == classes[0]:
        y_testt[i,:] = [1,0,0]
    elif y_test[i] == classes[1]:
        y_testt[i,:] = [0,1,0]
    elif y_test[i] == classes[2]:
        y_testt[i,:] = [0,0,1]
        

model1 = Sequential()
model1.add(Dense(32, input_shape=input_shape, activation='relu'))
model1.add(Dense(32, activation='relu'))
model1.add(Dense(num_classes, activation='softmax'))

model1.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model1.fit(x_train, y_trainn, epochs=100, verbose=1)
y_pred_mlp1 = model1.evaluate(x_test, y_testt, verbose=1)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4293 - accuracy: 0.3333
# Epoch 2/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.3392 - accuracy: 0.3524
# Epoch 3/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.2625 - accuracy: 0.6095
# Epoch 4/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.2033 - accuracy: 0.3619
# Epoch 5/100
# 4/4 [==============================] - 0s 998us/step - loss: 1.1418 - accuracy: 0.3524
# Epoch 6/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0843 - accuracy: 0.3524
# Epoch 7/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0314 - accuracy: 0.3524
# Epoch 8/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.9802 - accuracy: 0.5524
# Epoch 9/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.9335 - accuracy: 0.6667
# Epoch 10/100
# ...
